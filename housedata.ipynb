# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as mpt

# %%
df = pd.read_csv("data.csv")

# %%
df.head(5)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.tail()
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
new_df = df.dropna()

# %%
new_df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.fillna(130, inplace = True)

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df.set_index('country')
# Out:
#                         date         price  bedrooms  bathrooms  sqft_living  \
# country
# USA      2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# USA      2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# USA      2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# USA      2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# USA      2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                      ...           ...       ...        ...          ...
# USA      2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# USA      2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# USA      2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# USA      2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# USA      2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
# ...

# %%
df.sort_values(by = 'price', ascending = False )
# Out:
#                      date       price  bedrooms  bathrooms  sqft_living  \
# 4350  2014-07-03 00:00:00  26590000.0       3.0       2.00         1180
# 4346  2014-06-23 00:00:00  12899000.0       3.0       2.50         2190
# 2286  2014-06-11 00:00:00   7062500.0       5.0       4.50        10040
# 2654  2014-06-17 00:00:00   4668000.0       5.0       6.75         9640
# 2761  2014-06-18 00:00:00   4489000.0       4.0       3.00         6430
# ...                   ...         ...       ...        ...          ...
# 4472  2014-06-09 00:00:00         0.0       4.0       3.75         4060
# 4567  2014-07-02 00:00:00         0.0       4.0       2.50         4080
# 4354  2014-05-05 00:00:00         0.0       3.0       1.75         1490
# 4454  2014-06-03 00:00:00         0.0       5.0       2.50         2090
# 4382  2014-05-12 00:00:00         0.0       5.0       4.50         4630
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
new_df = df.dropna(inplace = True)

# %%
new_df

# %%
df.sort_values(by = 'bedrooms', ascending = False)
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 241   2014-05-07 00:00:00   599999.0       9.0       4.50         3830
# 3911  2014-07-03 00:00:00   340000.0       8.0       2.75         2790
# 1500  2014-05-28 00:00:00  1970000.0       8.0       3.50         4440
# 1644  2014-05-30 00:00:00   840000.0       7.0       4.50         4290
# 291   2014-05-07 00:00:00   540000.0       7.0       5.75         3700
# ...                   ...        ...       ...        ...          ...
# 1216  2014-05-22 00:00:00   353000.0       1.0       1.00          550
# 1906  2014-06-04 00:00:00   129000.0       1.0       1.00          650
# 260   2014-05-07 00:00:00   250000.0       1.0       1.00         1100
# 2365  2014-06-12 00:00:00  1095000.0       0.0       0.00         3064
# 3209  2014-06-24 00:00:00  1295648.0       0.0       0.00         4810
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df1 = df.set_index('country')

# %%
df1
# Out:
#                         date         price  bedrooms  bathrooms  sqft_living  \
# country
# USA      2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# USA      2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# USA      2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# USA      2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# USA      2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                      ...           ...       ...        ...          ...
# USA      2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# USA      2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# USA      2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# USA      2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# USA      2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
# ...

# %%
missing_values = (df.isnull().sum())

# %%
missing_values
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
duplicate_values = (df.duplicated())

# %%
duplicate_values
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4595    False
# 4596    False
# 4597    False
# 4598    False
# 4599    False
# Length: 4600, dtype: bool

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
corela =(df.corr())

# %%
corela
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.200336   0.327110     0.430410  0.050451  0.151461
# bedrooms       0.200336  1.000000   0.545920     0.594884  0.068819  0.177895
# bathrooms      0.327110  0.545920   1.000000     0.761154  0.107837  0.486428
# sqft_living    0.430410  0.594884   0.761154     1.000000  0.210538  0.344850
# sqft_lot       0.050451  0.068819   0.107837     0.210538  1.000000  0.003750
# floors         0.151461  0.177895   0.486428     0.344850  0.003750  1.000000
# waterfront     0.135648 -0.003483   0.076232     0.117616  0.017241  0.022024
# view           0.228504  0.111028   0.211960     0.311009  0.073907  0.031211
# condition      0.034915  0.025080  -0.119994    -0.062826  0.000558 -0.275013
# sqft_above     0.367570  0.484705   0.689918     0.876443  0.216455  0.522814
# sqft_basement  0.210427  0.334165   0.298020     0.447206  0.034842 -0.255510
# ...

# %%
corela
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.200336   0.327110     0.430410  0.050451  0.151461
# bedrooms       0.200336  1.000000   0.545920     0.594884  0.068819  0.177895
# bathrooms      0.327110  0.545920   1.000000     0.761154  0.107837  0.486428
# sqft_living    0.430410  0.594884   0.761154     1.000000  0.210538  0.344850
# sqft_lot       0.050451  0.068819   0.107837     0.210538  1.000000  0.003750
# floors         0.151461  0.177895   0.486428     0.344850  0.003750  1.000000
# waterfront     0.135648 -0.003483   0.076232     0.117616  0.017241  0.022024
# view           0.228504  0.111028   0.211960     0.311009  0.073907  0.031211
# condition      0.034915  0.025080  -0.119994    -0.062826  0.000558 -0.275013
# sqft_above     0.367570  0.484705   0.689918     0.876443  0.216455  0.522814
# sqft_basement  0.210427  0.334165   0.298020     0.447206  0.034842 -0.255510
# ...

# %%
corela.plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind = 'hist', x = 'price', y = 'bedrooms')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
imp_features =['bedrooms', 'bathrooms', 'sqft_living','floors', 'condition', 'yr_built' ]

# %%
imp_features
# Out:
# ['bedrooms', 'bathrooms', 'sqft_living', 'floors', 'condition', 'yr_built']

# %%
x= df[imp_features]

# %%
x
# Out:
#       bedrooms  bathrooms  sqft_living  floors  condition  yr_built
# 0          3.0       1.50         1340     1.5          3      1955
# 1          5.0       2.50         3650     2.0          5      1921
# 2          3.0       2.00         1930     1.0          4      1966
# 3          3.0       2.25         2000     1.0          4      1963
# 4          4.0       2.50         1940     1.0          4      1976
# ...        ...        ...          ...     ...        ...       ...
# 4595       3.0       1.75         1510     1.0          4      1954
# 4596       3.0       2.50         1460     2.0          3      1983
# 4597       3.0       2.50         3010     2.0          3      2009
# 4598       4.0       2.00         2090     1.0          3      1974
# 4599       3.0       2.50         1490     2.0          4      1990
#
# [4600 rows x 6 columns]

# %%
y = df.price

# %%
y
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
import seaborn as sns

# %%
df_model= DecisionTreeRegressor(random_state = 1)

# %%
df_model.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print("making pridiction for the following 5 houses: ")
# Out:
# making pridiction for the following 5 houses:

# %%
print(x.head())
# Out:
#    bedrooms  bathrooms  sqft_living  floors  condition  yr_built
# 0       3.0       1.50         1340     1.5          3      1955
# 1       5.0       2.50         3650     2.0          5      1921
# 2       3.0       2.00         1930     1.0          4      1966
# 3       3.0       2.25         2000     1.0          4      1963
# 4       4.0       2.50         1940     1.0          4      1976

# %%
print("the pridictions are: ")
# Out:
# the pridictions are:

# %%
print(df_model.predict(x.head()))
# Out:
# [ 313000. 2384000.  342000.  420000.  550000.]

# %%
df_price_pred = df_model.predict(x)

# %%
df_price_pred
# Out:
# array([ 313000.      , 2384000.      ,  342000.      , ...,
#         416904.166667,  203400.      ,  220600.      ])

# %%
mean_absolute_error(y, df_price_pred)
# Out:
# 1821.2713250517393

# %%
train_x, val_x, train_y, val_y = train_test_split(x, y, random_state = 1)

# %%
df_model = DecisionTreeRegressor()

# %%
df_model.fit(train_x, train_y)
# Out:
# DecisionTreeRegressor()

# %%
df_price_pred = df_model.predict(val_x)

# %%
val_mae = mean_absolute_error(val_y, df_price_pred )

# %%
print("validation mae: {:,.0f}".format(val_mae))
# Out:
# validation mae: 273,083

# %%
def get_mae(max_leaf_nodes, train_x, val_x, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes = max_leaf_nodes, random_state = 0)
    model.fit(train_x, train_y)
    pred_val = model.predict(val_x)
    mae = mean_absolute_error(val_y, pred_val)
    return(mae)

# %%
candidate_max_leaf_nodes = [5, 25, 50, 100, 250, 500]

# %%
candidate_max_leaf_nodes
# Out:
# [5, 25, 50, 100, 250, 500]

# %%
#write loop to find the ideal tree sizes from candidate max leaf nodes

# %%
scores = {leaf_size : get_mae(leaf_size, train_x, val_x, train_y, val_y) for leaf_size in candidate_max_leaf_nodes}

# %%
best_tree_size = min(scores, key=scores.get)

# %%
final_model = DecisionTreeRegressor(max_leaf_nodes = best_tree_size, random_state = 1)

# %%
final_model.fit(train_x, train_y)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=5, random_state=1)

# %%
final_price_pred = final_model.predict(val_x)

# %%
mae_val = mean_absolute_error(val_y, final_price_pred)

# %%
print("validation MAE: {:,.0f}".format(mae_val))
# Out:
# validation MAE: 185,239
